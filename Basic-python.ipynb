# %%
import sys
sys.version
# Out:
# '3.12.7 | packaged by Anaconda, Inc. | (main, Oct  4 2024, 13:17:27) [MSC v.1929 64 bit (AMD64)]'

# %% [markdown]
# # work with numbers

# %%
3
# Out:
# 3

# %%
2
# Out:
# 2

# %%
3 + 2
# Out:
# 5

# %%
3 - 2
# Out:
# 1

# %%
3 * 2
# Out:
# 6

# %%
3 ** 2
# Out:
# 9

# %% [markdown]
# # work with string

# %%
ganeshambati
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 ganeshambati
#
# NameError: name 'ganeshambati' is not defined

# %%
'ganeshambati'
# Out:
# 'ganeshambati'

# %%
" ganeshambati "
# Out:
# ' ganeshambati '

# %%
''' ganeshambati '''
# Out:
# ' ganeshambati '

# %% [markdown]
# # variable = object

# %%
v = 5 # v-variable and 5 is value
v
# Out:
# 5

# %%
v1 = 'ganesh'
v2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 2
#       1 v1 = 'ganesh'
# ----> 2 v2
#
# NameError: name 'v2' is not defined

# %%
v1
# Out:
# 'ganesh'

# %%
a = 5.5
type(a)
# Out:
# float

# %%
import sys
syst.version
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 2
#       1 import sys
# ----> 2 syst.version
#
# NameError: name 'syst' is not defined

# %%
nit = 15
NIT
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 2
#       1 nit = 15
# ----> 2 NIT
#
# NameError: name 'NIT' is not defined

# %%
nit
# Out:
# 15

# %%
1a = 67
1a
# Out:
#   Cell In[27], line 1
#     1a = 67
#     ^
# SyntaxError: invalid decimal literal

# %%
a1 = 67
a1
# Out:
# 67

# %%
nit$ = 89
nit$
# Out:
#   Cell In[32], line 1
#     nit$ = 89
#        ^
# SyntaxError: invalid syntax

# %%
x_train, x_test, y_train, y_test = 80,20,70,30

# %%
x_train
x_test
y_train
y_test
# Out:
# 30

# %%
print(x_train)
print(x_test)
print(y_train)
print(y_test)
# Out:
# 80
# 20
# 70
# 30

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
if = 90
if
# Out:
#   Cell In[44], line 1
#     if = 90
#        ^
# SyntaxError: invalid syntax

# %%
a10 = 78
a9 = 80

# %%
print(a10)
print(a9)
# Out:
# 78
# 80

# %%
del a10

# %%
a10
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 a10
#
# NameError: name 'a10' is not defined

# %%
for = 90
# Out:
#   Cell In[54], line 1
#     for = 90
#         ^
# SyntaxError: invalid syntax

# %%
For = 90
For
# Out:
# 90

# %%
a = True
a
# Out:
# True

# %%
b = 'true'
b
# Out:
# 'true'

# %%
pi = 3.17
pi
# Out:
# 3.17

# %%
pi = 3.20
pi
# Out:
# 3.2

# %%
aaaaaaaaaaaaaaaaaaaaaa = 90
aaaaaaaaaaaaaaaaaaaaaa
# Out:
# 90

# %% [markdown]
# # variable are completed
